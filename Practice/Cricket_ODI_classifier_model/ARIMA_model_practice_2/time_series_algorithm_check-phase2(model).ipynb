# %% [markdown]
# # case1- utilization

# %%
import pandas as pd
df1 = pd.read_excel(r'D:\ML\ts\git\usage_sample_ts.xlsx', sheet_name='case1')
df2 = pd.read_excel(r'D:\ML\ts\git\usage_sample_ts.xlsx', sheet_name='case2')

df1 = df1[['Time', 'Utilisation']]
df1['Time'] = pd.to_datetime(df1['Time'])
df1.set_index('Time', inplace=True)


import statsmodels.api as sm
sarima_model = sm.tsa.statespace.SARIMAX(df1['Utilisation'], order=(2, 1, 4), seasonal_order=(0, 1, 0, 24), enforce_invertibility=False, enforce_stationarity=False)
result_sarima = sarima_model.fit()


pred_ts = pd.date_range(df1.index[-1], periods=25, freq='H')[1:]
pred_df = pd.DataFrame(pred_ts, columns=['Time'])
pred_df.set_index('Time', inplace=True)
df1 = pd.concat([df1, pred_df])
predicted_series = result_sarima.predict(start=0, end=192)
result_df = pd.concat([df1, pd.DataFrame(predicted_series)], ignore_index=True, axis=1)
result_df.columns = ['cpu_usage_actual', 'cpu_usage_predicted']
result_df.plot(figsize=(15,5))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "

# %% [markdown]
# # case2- utilization

# %%
df2 = pd.read_excel(r'D:\ML\ts\git\usage_sample_ts.xlsx', sheet_name='case2')

df2 = df2[['Time', 'Utilisation']]
df2['Time'] = pd.to_datetime(df2['Time'])
df2.set_index('Time', inplace=True)


import statsmodels.api as sm
sarima_model = sm.tsa.statespace.SARIMAX(df2['Utilisation'], order=(2, 1, 4), seasonal_order=(0, 1, 0, 24), enforce_invertibility=False, enforce_stationarity=False)
result_sarima = sarima_model.fit()


pred_ts = pd.date_range(df2.index[-1], periods=25, freq='H')[1:]
pred_df = pd.DataFrame(pred_ts, columns=['Time'])
pred_df.set_index('Time', inplace=True)
df2 = pd.concat([df2, pred_df])
predicted_series = result_sarima.predict(start=0, end=192)
result_df = pd.concat([df2, pd.DataFrame(predicted_series)], ignore_index=True, axis=1)
result_df.columns = ['cpu_usage_actual', 'cpu_usage_predicted']
result_df.plot(figsize=(15,5))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "

# %% [markdown]
# # case1-  Memory usage

# %%
import pandas as pd
df1 = pd.read_excel(r'D:\ML\ts\git\usage_sample_ts.xlsx', sheet_name='case1')


df1 = df1[['Time', 'Memory']]
df1['Time'] = pd.to_datetime(df1['Time'])
df1.set_index('Time', inplace=True)


import statsmodels.api as sm
sarima_model = sm.tsa.statespace.SARIMAX(df1['Memory'], order=(2, 1, 4), seasonal_order=(0, 1, 0, 24), enforce_invertibility=False, enforce_stationarity=False)
result_sarima = sarima_model.fit()


pred_ts = pd.date_range(df1.index[-1], periods=25, freq='H')[1:]
pred_df = pd.DataFrame(pred_ts, columns=['Time'])
pred_df.set_index('Time', inplace=True)
df1 = pd.concat([df1, pred_df])
predicted_series = result_sarima.predict(start=0, end=192)
result_df = pd.concat([df1, pd.DataFrame(predicted_series)], ignore_index=True, axis=1)
result_df.columns = ['memory_usage_actual', 'memory_usage_predicted']
result_df.plot(figsize=(15,5))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'

# %% [markdown]
# # case2-  Memory usage

# %%
df2 = pd.read_excel(r'D:\ML\ts\git\usage_sample_ts.xlsx', sheet_name='case2')

df2 = df2[['Time', 'Memory']]
df2['Time'] = pd.to_datetime(df2['Time'])
df2.set_index('Time', inplace=True)


import statsmodels.api as sm
sarima_model = sm.tsa.statespace.SARIMAX(df2['Memory'], order=(2, 1, 4), seasonal_order=(0, 1, 0, 24), enforce_invertibility=False, enforce_stationarity=False)
result_sarima = sarima_model.fit()


pred_ts = pd.date_range(df2.index[-1], periods=25, freq='H')[1:]
pred_df = pd.DataFrame(pred_ts, columns=['Time'])
pred_df.set_index('Time', inplace=True)
df2 = pd.concat([df2, pred_df])
predicted_series = result_sarima.predict(start=0, end=192)
result_df = pd.concat([df2, pd.DataFrame(predicted_series)], ignore_index=True, axis=1)
result_df.columns = ['cpu_usage_actual', 'cpu_usage_predicted']
result_df.plot(figsize=(15,5))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   warnings.warn('No frequency information was'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "

# %% [markdown]
# ## 5min intervel utilization prediction

# %%
import pandas as pd
df3 = pd.read_excel(r'D:\ML\ts\git\5min.xlsx', sheet_name='5min')


df3 = df3[['Time', 'Utilisation']]
df3['Time'] = pd.to_datetime(df3['Time'])
df3.set_index('Time', inplace=True)


import statsmodels.api as sm
sarima_model = sm.tsa.statespace.SARIMAX(df3['Utilisation'], order=(2, 1, 4), seasonal_order=(0, 1, 0, 288), enforce_invertibility=False, enforce_stationarity=False)
result_sarima = sarima_model.fit()


pred_ts = pd.date_range(df3.index[-1], periods=288, freq='5min')[1:]
pred_df = pd.DataFrame(pred_ts, columns=['Time'])
pred_df.set_index('Time', inplace=True)
df3 = pd.concat([df3, pred_df])
predicted_series = result_sarima.predict(start=576, end=1151)
result_df = pd.concat([df3, pd.DataFrame(predicted_series)], ignore_index=True, axis=1)
result_df.columns = ['cpu_usage_actual', 'cpu_usage_predicted']
result_df.plot(figsize=(15,5))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency 5T will be used.
#   warnings.warn('No frequency information was'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency 5T will be used.
#   warnings.warn('No frequency information was'
